# %%
import os
import pandas as pd
import requests
import json
import re
import csv
import datetime
import numpy as np

# %%
# 手順
# interco api のレスポンス結果取得

# json結果から、テキストを出力

# curl https://api.intercom.io/conversations/21734935255?display_as=plaintext  -H 'Authorization:Bearer dG9rOjNlMzM1MTY3XzM2OTBfNGZiZF85OWY3XzNiMzEwZmI4ZjRkYzoxOjA=' -H 'Accept:application/json'

# jsonをCSVファイルに保存

# %%
##############################
# 非同期＆スクレイピング＆CSV生成
##############################
def expo(arr):
    # 現在時刻生成
    now = datetime.datetime.now()
    d = now.strftime("%Y%m%d%H%M%S")

    # CSVファイル生成
    output_name ="data.csv" #出力CSVの名前

    write_fp=csv.writer(open(output_name, "w"))
    write_fp.writerow(["更新日時",d]) #CSVに更新日時追加
    write_fp.writerow(["Conversation ID","comment"]) #CSVに見出し追加
    
    # intercom api Token
    # 検証用
#     access_token = "Bearer dG9rOjNlMzM1MTY3XzM2OTBfNGZiZF85OWY3XzNiMzEwZmI4ZjRkYzoxOjA=" 
    #本番用
    access_token = "Bearer " + "dG9rOmFkNTVhNzA0X2ZkMTdfNGE4Zl84YTVmXzYzNjBjMWZiN2MyMToxOjA=" 

    headers = {
        "Authorization": access_token,
        "Accept": 'application/json'
    }

    ##############################
    # request
    ##############################
    print("合計",len(arr))
    
    for index in range(len(arr)):
        print((index+1),"/",len(arr))
        get_url = "https://api.intercom.io/conversations/" + str(arr[index]) 
        r = requests.get(get_url, headers=headers)         
        j = r.json()
        
        convID = arr[index]
        convText = ' '.join(get_txt(j))
        write_fp.writerow([convID,convText]) #CSVに追加


##############################
# 言語データ成形
##############################
def get_txt(arg):
    arr = []    
    if isinstance(arg, list):
        for val in arg:
            arr += get_txt(val)
    elif isinstance(arg, dict):
        for key in arg.keys():

            #api のbodyにNone以外はすべて格納
            if key == 'body' and  str(arg[key] ) != "None":
                # HTMLパース
                p = re.compile(r"<[^>]*?>")
                plainTxt = p.sub("", arg[key])
                arr.append(plainTxt)
            else:
                arr += get_txt(arg[key])
    return arr

##############################
# 実行method　： 処理するCSVデータ取得（list形式）
##############################
rowdata_csv_file = 'q_driver_19_06.csv'
data = np.ravel(pd.read_csv(rowdata_csv_file,usecols=['Conversation ID']).values.tolist())
# data = [21646018446,21734935255,21646029060,21646007222]
# data = [20641142077,20641142077]

expo(data)
print("DONE")
# Out:
# 合計 1320
# 1 / 1320
# 2 / 1320
# 3 / 1320
# 4 / 1320
# 5 / 1320
# 6 / 1320
# 7 / 1320
# 8 / 1320
# 9 / 1320
# 10 / 1320
# 11 / 1320
# 12 / 1320
# 13 / 1320
# 14 / 1320
# 15 / 1320
# 16 / 1320
# 17 / 1320
# 18 / 1320
# 19 / 1320
# 20 / 1320
# 21 / 1320
# 22 / 1320
# 23 / 1320
# 24 / 1320
# 25 / 1320
# 26 / 1320
# 27 / 1320
# 28 / 1320
# 29 / 1320
# 30 / 1320
# 31 / 1320
# 32 / 1320
# 33 / 1320
# 34 / 1320
# 35 / 1320
# 36 / 1320
# 37 / 1320
# 38 / 1320
# 39 / 1320
# 40 / 1320
# 41 / 1320
# 42 / 1320
# 43 / 1320
# 44 / 1320
# 45 / 1320
# 46 / 1320
# 47 / 1320
# 48 / 1320
# 49 / 1320
# 50 / 1320
# 51 / 1320
# 52 / 1320
# 53 / 1320
# 54 / 1320
# 55 / 1320
# 56 / 1320
# 57 / 1320
# 58 / 1320
# 59 / 1320
# 60 / 1320
# 61 / 1320
# 62 / 1320
# 63 / 1320
# 64 / 1320
# 65 / 1320
# 66 / 1320
# 67 / 1320
# 68 / 1320
# 69 / 1320
# 70 / 1320
# 71 / 1320
# 72 / 1320
# 73 / 1320
# 74 / 1320
# 75 / 1320
# 76 / 1320
# 77 / 1320
# 78 / 1320
# 79 / 1320
# 80 / 1320
# 81 / 1320
# 82 / 1320
# 83 / 1320
# ...
