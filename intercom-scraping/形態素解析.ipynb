# %%
import MeCab
import pandas as pd
import sqlite3

import re
from collections import Counter
import csv
import datetime

#wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 現在時刻生成
now = datetime.datetime.now()
d = now.strftime("%Y%m%d%H%M%S")

# %%
csv_file = 'data.csv'
data = str(pd.read_csv(csv_file,skiprows=[0,1],usecols=[1],header=None))


print(data)
# Out:
#                                                       1
# 0     これから参加します。よろしくお願いします。 対応します 森田さんCREWの佐藤です。ご連絡い...
# 1     すいません。設定で連携する地図を選択できるメニューがありますが、切り替えてもGoogleのま...
# 2     お疲れ様です。今日はこれにて失礼します。 送ります 笹倉さん、お疲れ様です。CREWの矢島で...
# 3     終了しますね🎵 金森さん     ドライブお疲れさまでした。　CREWの野口です。     ...
# 4     すみません。明日22時スタートで参加予定ですが、すみません23時から仕事が入ってしまいました...
# 5     休憩します。\nあとアプリの調子がわるいみたいです 対応します。 堀越さんCREWの佐藤です...
# 6     ユーザー名の変更完了 対応します https://api.crewcrew.jp/admin...
# 7     今日はこれで終了します！ありがとうございました。 対応します。 宮嶋さんこんばんは。CREW...
# 8     終了します おくります 小川さん、お疲れ様です。CREWの佐藤です。本日も遅い時間まで参加し...
# 9     今日はこれで終了します 送ります 平野さん、お疲れ様です。CREWの矢島です。ご連絡ありがと...
# 10    古いクレジットカード情報を削除するにはどうしたら良いですか？カードの期限が切れて、同じ番号で...
# 11    ちょっとだけドライブします taiousimasu このメッセージは削除されました 中村さん...
# 12    本日のドライブ、終了しました。お疲れ様でした。 送ります 野口さん、お疲れ様です。CREWの...
# 13    たまたま、丸の内通った時にドライブモードをオンにしたらマッチングしましたので1組のせました。...
# 14    いつもお世話になります。ドライバーもライダーもやる竹内です。グレードプログラムのことについて...
# 15    本日25時27時参加希望です。\n計算されているガソリン代車によって違うのですか？それとも平...
# 16    お世話になります。及川です。\n本日の参加枠はまだ残ってますでしょうか？\n21:30ごろ〜...
# 17    業務の方は 再開されたのでしょうか？ どうゆうこっちゃねん！！ 😂 メンテナンスのことかあ💂...
# 18    お世話になります。先日登録をしました木村です。各種必要書類を登録し、6／4研修を受ける予定で...
# 19    昨日のドライブで、最後のライダーさんからの評価が届いていませんでした。何か対応する必要があり...
# 20    今日22時から24時で入りたいのですが、いかがでしょうか。突然ですが、すみません。 大島さん...
# 21    お世話になります。本日20:00~24:00(少し前)参加希望します。宜しくお願いします。辰...
# 22    こんばんは、本田です。本日、23時よりラストまで参加可能でしたら、お願いします。 やり 本田...
# 23    車検証の件間に合わないかもしれないのですがどうしたらいいでしょうか？先程、別の担当者にメッセ...
# 24    先程、牧野というライダーとマッチして、向かったら向かっている途中で「5分以内で来れますか？」...
# 25    現在 トイレ休憩中🚽 送ります 若葉です おっと、、、失礼しました🙇 小林さん、こんばんは。...
# 26    マップが更新されません 対応します 杉山 不具合多いみたいですが、再起動のご案内でいいのでし...
# 27    お世話になります。本日、今から24時頃まで活動できます。短い時間ですが、可能でしょうか？ 対...
# 28    この後、25時頃まで出来ますがいかがですか？ 対応します 桑原さん、ご連絡ありがとうございま...
# 29                          ライドしました この後どうすればいいですか 別窓対応中
# ...                                                 ...
# 1290  今、渋谷ですが、最後の成田さん、酔っ払っていて電話で会話しても話になりません。私は品の立って...
# 1291  キャンセル料を請求できないケースはどんな時ですか？教えてください。 松本さんおはようございま...
# 1292  アンケート、メールきていません @CSチーム　公式こちらご対応お願いします CS　アンケート...
# 1293  お疲れさまです。\n岩田先生から、月曜日にお会いしたいとご連絡あったのてすが、時間が決まらな...
# 1294   や 確認中 赤松 700円の補填が完了しました ありがとうございます！ 田村さん\nCRE...
# 1295  お手数おかけします。処置は後ほど致しますよろしくお願いします。 CREW コンプライアンスチ...
# 1296  ライダーからのキャンセルでキャンセル料が発生した場合は受け取り金額に計上されるんですか？ C...
# 1297  お世話になります。山口です。本日空きがあるようなら、21-23時くらいでドライブしようと思い...
# 1298  【プロフィールコメント変更要望】私のプロフィールのコメントが同じ文が連続になってしまってるの...
# 1299  こんにちは。本日のドライブ枠の空きはありますか？21時〜27時希望です。よろしくお願いします...
# 1300  申し込んでいませんが本日、ドライブ可能ですか？21時〜2時を希望します。 CS　シフト やり...
# 1301  今日も20時から24時で出ようと思います シフト やり ブラリ、、、 なんで😱 未決済BAN...
# 1302  お疲れ様です本日2000-2700で空きがありましたら、参加希望です。よろしくお願いします。...
# 1303  宮崎くん、仕事してるなら先日のお返事ください。 CREW コンプライアンスチーム  小川 深...
# 1304  お世話になります。9時から25時まで枠ありますか？ 対応します。 坪沼さんご連絡いただきあり...
# 1305  短い時間ですが、これからドライブ始めたいと思います。 対応します。 山口さんこんばんは。CR...
# 1306  マッチング中なのにリクエストがパンバン来ます 対応します。 https://api.crew...
# 1307  先ほど受けた恵比寿南のライダーはキャンセルになったのですか？ 確認します 鶴久さん\nお疲れ...
# 1308  傘を忘れた方がいます 対応します 加藤さん\nCREWサポートチームの高橋です。ご連絡ありが...
# 1309  お世話になってます。今週の予約について、下記の日程でお願いします。\n7/1(月)20時〜2...
# 1310  今日はこれで終わりにしたいと思います。 対応します。 山口さんこんばんは。CREWサポートチ...
# 1311  こんばんは。ガソリン代補助の申請のため、レシートの写しをお送りしたいのですが、どちらに送れば...
# 1312  星の数はアプリのどこから確認すればよろしいでしょうか。 対応します 加藤さん\nご質問ありが...
# 1313  本日参加希望です23:00〜2:00途中オフします 対応します 小森さんこんばんは。CREW...
# 1314  昨日載せた方で、まだ評価を頂いて無い方がいますが、運営からちゃんと評価するよう、フォローされ...
# 1315  こんばんは。今から27時まで飛び入り参加してもよろしいですか？ たいおうします 山口さんこん...
# 1316  お疲れ様です。後ほど2時間程度参加可能でしょうか？ 対応します 有馬さん、こんばんは。CRE...
# 1317  お疲れ様です。只今より始めます。宜しくお願い致します。 対応します 関さん、こんばんは。CR...
# 1318  今から参加しても大丈夫ですか? おくります。 森武さんこんばんは CREWサポートチームの佐...
# 1319  クルーします。 対応します 新蔵さん、こんばんは。CREWサポートチームの高橋です。本日もご...
#
# [1320 rows x 1 columns]

# %%
#形態素解析    
# パース
# mecab = MeCab.Tagger()
mecab = MeCab.Tagger('-d /usr/local/lib/mecab/dic/mecab-ipadic-neologd')
parse = mecab.parse(data)
lines = parse.split('\n')
items = (re.split('[\t,]', line) for line in lines)

#ワードクラウド用のテキスト格納
w = '' #ワードクラウド用の名詞を格納

# 名詞抽出
for item in items:
    # 名詞のみ抽出
#     if item[0] not in ('EOS', '', 't', 'ー') and item[1] == '名詞' and item[2] == '一般' :
    if item[0] not in ('EOS', '', 't', 'ー') and item[1] == '名詞' :
        #print(item[0])
        w += " " + item[0]

# ワードクラウド生成
wordcloud = WordCloud(background_color="white"
                      ,font_path="/System/Library/Fonts/ヒラギノ角ゴシック W3.ttc"
                      ,width=800
                      ,height=500).generate(w)

# 画像生成
plt.imshow(wordcloud)
plt.show()

# %%
csv_file = 'data.csv'
data = str(pd.read_csv(csv_file,skiprows=[0,1],usecols=[1],header=None))

#形態素解析  名詞バージョン
# パース
mecab = MeCab.Tagger('-d /usr/local/lib/mecab/dic/mecab-ipadic-neologd')
parse = mecab.parse(data)
lines = parse.split('\n')
items = (re.split('[\t,]', line) for line in lines)

# 名詞をリストに格納
cnt_words = [item[0]
         for item in items
         if (item[0] not in ('EOS', '', 't', 'ー') and
#              item[1] == '名詞')]
             item[1] == '名詞' and item[2] == '一般')]

print(cnt_words)
# CSVファイル生成   
output_name ="output.csv" #出力CSVの名前
write_fp=csv.writer(open(output_name, "w"))
write_fp.writerow(["更新日時",d]) #CSVに更新日時追加
write_fp.writerow(["名詞","count"]) #CSVに見出し追加

# 頻度順に出力
counter = Counter(cnt_words)
#print(counter)
for word, count in counter.most_common():
    write_fp.writerow([word,count]) #CSVに見出し追加
    print(f"{word}\t{count}")
# Out:
# ['地図', 'メニュー', '疲れ', 'あと', '調子', 'クレジットカード', '情報', 'カード', '期限', '番号', 'メッセージ', 'モード', 'ドライバー', 'ライダー', 'グレード', 'ガソリン', '平', '業務', '😂', 'メンテナンス', '💂', '各種', '書類', '最後', 'ライダー', '辰', 'こんばんは', 'ラスト', '件', '別', 'ライダー', 'トイレ', '若葉', 'マップ', 'でし', 'ライド', '窓', '最後', '品', 'ケース', 'アンケート', 'チーム', 'アンケート', '疲れ', '先生', '会い', 'す', '赤松', 'お手数', 'コンプライアンスチ', 'ライダー', '受け取り', '金額', '空き', 'プロフィール', 'プロフィール', '文', '空き', '未決済', '疲れ', '空き', 'チーム', '枠', 'いただき', 'リクエスト', 'パン', '先', 'ライダー', '疲れ', '傘', 'チーム', '下記', '日程', '月', 'サポートチ', 'こんばんは', 'ガソリン', 'レシート', '写し', '数', 'どこか', 'い方', 'こんばんは', 'いおう', 'さんこん', '疲れ', 'CRE', '疲れ', '只今', 'チーム', '佐', 'クルー', 'チーム', 'rows', 'x', 'columns']
# 疲れ	6
# ライダー	5
# チーム	5
# こんばんは	3
# 空き	3
# ガソリン	2
# 最後	2
# アンケート	2
# プロフィール	2
# 地図	1
# メニュー	1
# あと	1
# 調子	1
# クレジットカード	1
# 情報	1
# カード	1
# 期限	1
# 番号	1
# メッセージ	1
# モード	1
# ドライバー	1
# グレード	1
# 平	1
# 業務	1
# 😂	1
# メンテナンス	1
# 💂	1
# 各種	1
# 書類	1
# 辰	1
# ラスト	1
# 件	1
# 別	1
# トイレ	1
# 若葉	1
# マップ	1
# でし	1
# ライド	1
# 窓	1
# 品	1
# ケース	1
# 先生	1
# 会い	1
# す	1
# 赤松	1
# お手数	1
# コンプライアンスチ	1
# 受け取り	1
# 金額	1
# 文	1
# 未決済	1
# 枠	1
# いただき	1
# リクエスト	1
# パン	1
# 先	1
# 傘	1
# 下記	1
# 日程	1
# 月	1
# サポートチ	1
# レシート	1
# 写し	1
# 数	1
# どこか	1
# い方	1
# いおう	1
# さんこん	1
# CRE	1
# 只今	1
# 佐	1
# クルー	1
# rows	1
# x	1
# columns	1
